# %% [markdown]
# # **Analisis Faktor-Faktor yang Mempengaruhi Ketertarikan Pelamar terhadap Citra Perusahaan di Indonesia pada 13 Desember 2021**

# %% [markdown]
# #**Import Library**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan bisnis dari dataset ini adalah mengidentifikasi faktor-faktor yang paling dipertimbangkan oleh pelamar saat ingin mendaftar kerja seperti Jenis Perusahaan, Deskripsi Pekerjaan, dan Jenis Kontrak Kerja, Gaji dan Selling Points setiap perusahaan. Dari hal tersebut dapat menemukan citra setiap perusahaan yang menjadi pertimbangan pelamar.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini adalah tingginya angka pengangguran di Indonesia. Bahkan Menurut data Tranding Economy, Tingkat Pengangguran di Indonesia mencapai 5.45% peringkat 11 dunia. Namun terdapat kesenjangan keterampilan yang dimiliki dan yang dibutuhkan perusahaan. hal ini menjadi kesempatan bagi perusahaan untuk membangun citra positif.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Tujuan dari Data Mining pada dataset ini adalah untuk memahami ketertarikan pelamar terutama gen z berdasarkan faktor-faktor yang mempengaruhi branding perusahaan dan mengembangkan model untuk memahami preferensi pelamar berdasarkan karakteristik seperti jenis kelamin, usia dan pengalaman kerja

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Proyek ini bertujuan agar perusahaan memahami pasar tenaga kerja. untuk memenuhi itu, langkah pertama adalah mempelajari kondisi pasar tenaga kerja dan tantangan yang dihadapi perusahaan saat proses rekrutmen. lalu menganalisis data untuk mengidentifikasi tren pekerjaan dan memprediksi kebutuhan tenaga kerja di masa yang akan datang. project plan ini melibatkan penjadwalan dan komunikasi dengan tim maupun stake holder agar komunikasi dapar berjalan dengan baik terutama saat mengambil keputusan strategis terkait rekrutmen dan manajemen tenaga kerja

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# Jelaskan darimana sumber data kalian di sini, sertakan linknya juga ya

# %%
df = 'https://raw.githubusercontent.com/amaliakartikasari/Mini-Project-Data-Mining/main/Check%20Point%201/jobstreet_2021-12-13.csv'
df_file = pd.read_csv(df)
df_file
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 3      standout        508,193
# 4      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName            companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...               439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak               428988
# 2                        Pendidikan/Pelatihan,Pendidikan               428988
# 3      Komputer/Teknologi Informasi,IT-Admin Jaringan...  jobstreet-id-184662
# 4                        Pendidikan/Pelatihan,Pendidikan               428988
# ...                                                  ...                  ...
# ...

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
jumlah_baris, jumlah_kolom = df_file.shape

# Hapus spasi tak terputus di baris ini
print(f"Jumlah baris dalam dataset: {jumlah_baris}")
print(f"Jumlah kolom dalam dataset: {jumlah_kolom}")
# Out:
# Jumlah baris dalam dataset: 27677
# Jumlah kolom dalam dataset: 22

# %% [markdown]
# Pada dataset Jobstreet ini terdapat 27.677 record data dengan jumlah kolom pada dataset sebanyak 22 kolom.

# %% [markdown]
# ####Informasi Lanjutan

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27677 entries, 0 to 27676
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   adType           27677 non-null  object
#  1   categoriesCode   27677 non-null  object
#  2   categoriesName   27677 non-null  object
#  3   companyId        26789 non-null  object
#  4   companyName      26789 non-null  object
#  5   companyPrivate   27677 non-null  bool
#  6   description      27677 non-null  object
#  7   employment       26150 non-null  object
#  8   id               27677 non-null  int64
#  9   isClassified     27677 non-null  bool
#  10  isStandout       27677 non-null  bool
#  11  jobTitle         27677 non-null  object
#  12  jobUrl           27677 non-null  object
#  13  locations        27643 non-null  object
#  14  postingDuration  27677 non-null  object
#  15  postedAt         27677 non-null  object
#  16  salarycurrency   7150 non-null   object
# ...

# %% [markdown]
# Pada dataset ini terdapat 22 kolom dimana setiap kolom non-null, yaitu adType (dengan jumlah record data sebanyak 27677 dengan tipe data object), categoriesCode (dengan jumlah record data sebanyak 27677 dengan tipe data object), categoriesName (dengan jumlah record data sebanyak 27677 dengan tipe data object), companyId (dengan jumlah record data sebanyak 26789 dengan tipe data object), companyName (dengan jumlah record data sebanyak 26789 dengan tipe data object), companyPrivate (dengan jumlah record data sebanyak 27677 dengan tipe data bool), description (dengan jumlah record data sebanyak 27677 dengan tipe data object), employment (dengan jumlah record data sebanyak 26150 dengan tipe data object), id (dengan jumlah record data sebanyak 27677 dengan tipe data int64), isClassified (dengan jumlah record data sebanyak 27677 dengan tipe data bool), isStandout (dengan jumlah record data sebanyak 27677 dengan tipe data bool), jobTitle(dengan jumlah record data sebanyak 27677 dengan tipe data object), jobUrl (dengan jumlah record data sebanyak 27677 dengan tipe data object), locations (dengan jumlah record data sebanyak 27643 dengan tipe data object), postingDuration (dengan jumlah record data sebanyak 27677 dengan tipe data object), postedAt (dengan jumlah record data sebanyak 27677 dengan tipe data object), salarycurrency (dengan jumlah record data sebanyak 7150 dengan tipe data object), salaryMin (dengan jumlah record data sebanyak 7147 dengan tipe data float64), salaryMax (dengan jumlah record data sebanyak 7147 dengan tipe data float64), salaryPeriod (dengan jumlah record data sebanyak 27674 dengan tipe data object), salaryTerm (dengan jumlah record data sebanyak 0 dengan tipe data float64) dan sellingPoints (dengan jumlah record data sebanyak 4090 dengan tipe data object).

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
df_file.describe()
# Out:
#                  id     salaryMin     salaryMax  salaryTerm
# count  2.767700e+04  7.147000e+03  7.147000e+03         0.0
# mean   6.271764e+07  5.989785e+06  8.529533e+06         NaN
# std    2.388282e+08  6.807645e+06  1.099144e+07         NaN
# min    3.516206e+06  6.000000e+00  9.000000e+00         NaN
# 25%    3.697162e+06  3.500000e+06  4.900000e+06         NaN
# 50%    3.705158e+06  4.500000e+06  6.300000e+06         NaN
# 75%    3.712926e+06  6.500000e+06  9.800000e+06         NaN
# max    1.029882e+09  4.000000e+08  7.000000e+08         NaN

# %% [markdown]
# Berdasarkan tabel deskriptif di atas terlihat bahwa nilai keseluruhan pada tabel salaryMin adalah 7.147.000 dengan nilai rata-rata 5.989.785 dengan gaji minimal terendah adalah 6.000.000 dan gaji minimal terbesar adalah 400.000.000. Pada gaji maksimum nilai rata-rata adalah 8.529.533 dengan gaji maksimum terendah adalah 9.000.000 dengan gaji maksimum tertinggi adalah 700.000.000

# %% [markdown]
# Jangan lupa berikan penjelasan juga disini yaa (tiap - tiap kolomnya)

# %% [markdown]
# ##**Exploratory Data Analysis**

# %%
df_file['salaryMin'].plot(kind='line', figsize=(8, 4), title='salaryMin')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Pada visualisasi di atas dapat dilihat bahwa perhitungan statistik sebelumnya tidak mengalami peningkatan secara signifikan pada count, mean, std maupun pada gaji minimal terendah. namun dapat dilihat bahwa terjadi lonjakan yang signifikan untuk gaji terendah paling tinggi.

# %% [markdown]
# TAMBAHKAN VISUALISASI KORELASI BESERTA PENJELASANNYA LEBIH BAIK

# %%
import plotly.express as px


px.imshow(df_file.corr(numeric_only=True))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Pada data di atas pada company private tidak terdapat faktor yang berpengaruh signifikan terhadap company private itu sendiri. pada id, tidak ada faktor yang mempengaruhi id tersebut, begitu pula pada isStandOut. sedangkan pada salaryMin, salaryMax berpengaruh signifikan terhadap salaryMax. jika salaryMin tinggi maka salaryMax akan semakin tinggi begitu juga sebaliknya.

# %%
import matplotlib.pyplot as plt

# Get the counts of each unique ad type
ad_type_counts = df_file["adType"].value_counts()

# Extract labels and values for the pie chart
ad_types = list(ad_type_counts.index)
ad_type_values = list(ad_type_counts.values)

# Define a list of custom colors (replace with your preferred colors)
colors = ["red","silver", "grey"]  # Adjust the number of colors based on ad_types

# Create the pie chart with custom colors
plt.pie(ad_type_values, labels=ad_types, autopct="%1.1f%%", colors=colors)
plt.title("Distribution of Ad Types")
plt.show()

# %% [markdown]
# pada visualisasi di atas, pada kolom adType terdapat tiga jenis pekerjaan yaitu standard, standout dan auto_inclusion. standard yang dimaksud adalah pekerjaan yang umum dengan persyaratan dan kualifikasi standar, dalam diagram di atas dapat dilihat bahwa standard memiliki potongan yang paling besar yaitu 55.8%. standout adalah jenis pekerjaan yang lebih menantang dan membutuhkan skillset yang lebih spesifik dengan persyaratan yang lebih tinggi, pada diagram diatas dapat dilihat bahwa standout memiliki potongan yang lebih besar yaitu 38.4%. potongan lainnya adalah auto_inclusion dimana pekerjaan ini secara otomatis akan ditawarkan pada karyawan yang memenuhi syarat tertentu, dan dapat dilihat bahwa auto_inclusion memiliki potongan terendah yaitu 5.7%

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the data (optional, adjust filtering criteria if needed)
filtered_df = df_file[df_file["employment"].isin(["full_time", "contract", "part_time"])]

# Create the bar plot with color based on employment type
sns.barplot(x=filtered_df.employment,
            y=filtered_df.salaryMin,
            hue="employment",  # Use "employment" column for color differentiation
            palette="Set3",  # Use a color palette for better differentiation
            data=filtered_df,
            hue_order=["full_time", "contract", "part_time"])  # Set order of categories

plt.title("Salary Minimum Distribution by Employment Type")  # Add title for clarity
plt.xlabel("Employment Type")  # Add label for x-axis
plt.ylabel("Salary Minimum")  # Add label for y-axis

# Adjust y-axis range to ensure all bars are visible
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Pada Barplot diatas terlihat bahwa terdapat tiga kategori dalam employment yaitu full time, contract dan part_time. dalam barplot tersebut dapat dilihat bahwa bar full_time memiliki gaji minimum tertinggi yaitu 6.000.000 sedangkan contract sekitar 5.000.000 dan part time sekitar 3.000.000. maka dari data tersebut jenis kontrak kerja berpengaruh signifikan dengan gaji yang diperoleh.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
import pandas as pd

def identify_missing_values(df):
  """
  This function identifies missing values and calculates their percentage for each numerical column in a DataFrame.

  Args:
      df (pandas.DataFrame): The DataFrame to analyze.

  Returns:
      pandas.DataFrame: A DataFrame with columns 'Kolom' (column name) and 'Persentase Missing Values' (percentage of missing values).
  """

  results = []
  cols = df.select_dtypes(include=['float64', 'int64'])

  for col in cols:
    # Calculate percentage of missing values directly
    percent_missing_values = (df[col].isnull().sum() / len(df)) * 100
    results.append({'Kolom': col, 'Persentase Missing Values': percent_missing_values})

  # Create and format results DataFrame
  results_df = pd.DataFrame(results)
  results_df.set_index('Kolom', inplace=True)

  return results_df

# Example usage (assuming you have your DataFrame named 'df_file')
missing_values_df = identify_missing_values(df_file)
display(missing_values_df)
# Out:
#             Persentase Missing Values
# Kolom
# id                           0.000000
# salaryMin                   74.177115
# salaryMax                   74.177115
# salaryTerm                 100.000000

# %% [markdown]
# Pada kolom ID tidak memiliki missing values karena berfungsi sebagai pengenal unik setiap data yang menjadi ciri khas data tersebut. sedangkan pada salaryMin,salaryMax dan salaryTerm menunjukkan bahwa terdapat banyak data yang hanya berisi missing values

# %% [markdown]
# ####Outliers Values

# %%
results = []

cols = df_file.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_file[col].quantile(0.25)
  q3 = df_file[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_file[(df_file[col] < lower_bound) | (df_file[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_file))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df_file = pd.DataFrame(results)
results_df_file.set_index('Kolom', inplace=True)
results_df_file = results_df_file.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df_file)
# Out:
# Kolom       Persentase Outliers
# id                     6.723995
# salaryMin              2.019728
# salaryMax              1.882429
# salaryTerm             0.000000

# %% [markdown]
# Pada tabel di atas menunjukan 6.72% data pada kolom id teridentifikasi sebagai outlier, pada salaryMin terdapat 2.01% dan pada salaryMax sebanyak 1.88%. hal ini menunjukan bahwa terdapat beberapa data gaji minimum maupun maximum yang memiliki perbandingan nilai jauh lebih tinggi atau jauh lebih rendah dibandingkan data lainnya. pada kolom salaryTerm menunjukkan bahwa jangka waktu gaji tidak didefinisikan pada dataset.

# %% [markdown]
# ####Duplicated Values

# %%
df_file[df_file.duplicated()]
# Out:
# Empty DataFrame
# Columns: [adType, categoriesCode, categoriesName, companyId, companyName, companyPrivate, description, employment, id, isClassified, isStandout, jobTitle, jobUrl, locations, postingDuration, postedAt, salarycurrency, salaryMin, salaryMax, salaryPeriod, salaryTerm, sellingPoints]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# dapat dilihat bahwa hasil syntax menunjukkan tidak ada duplicated value

# %%
print((df_file.isna().sum() / len(df_file)) * 100)
# Out:
# adType               0.000000
# categoriesCode       0.000000
# categoriesName       0.000000
# companyId            3.208440
# companyName          3.208440
# companyPrivate       0.000000
# description          0.000000
# employment           5.517216
# id                   0.000000
# isClassified         0.000000
# isStandout           0.000000
# jobTitle             0.000000
# jobUrl               0.000000
# locations            0.122846
# postingDuration      0.000000
# postedAt             0.000000
# salarycurrency      74.166275
# salaryMin           74.177115
# salaryMax           74.177115
# salaryPeriod         0.010839
# salaryTerm         100.000000
# sellingPoints       85.222387
# dtype: float64

# %%
df_file[df_file['salaryTerm'].isnull()]
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 3      standout        508,193
# 4      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName            companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...               439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak               428988
# 2                        Pendidikan/Pelatihan,Pendidikan               428988
# 3      Komputer/Teknologi Informasi,IT-Admin Jaringan...  jobstreet-id-184662
# 4                        Pendidikan/Pelatihan,Pendidikan               428988
# ...                                                  ...                  ...
# ...

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# ##**Penanganan Missing Values**

# %% [markdown]
# ###Pengecekan Missing Values

# %%
print((df_file.isna().sum() / len(df_file)) * 100)
# Out:
# adType               0.000000
# categoriesCode       0.000000
# categoriesName       0.000000
# companyId            3.208440
# companyName          3.208440
# companyPrivate       0.000000
# description          0.000000
# employment           5.517216
# id                   0.000000
# isClassified         0.000000
# isStandout           0.000000
# jobTitle             0.000000
# jobUrl               0.000000
# locations            0.122846
# postingDuration      0.000000
# postedAt             0.000000
# salarycurrency      74.166275
# salaryMin           74.177115
# salaryMax           74.177115
# salaryPeriod         0.010839
# salaryTerm         100.000000
# sellingPoints       85.222387
# dtype: float64

# %% [markdown]
# pada bagian ini digunakan untuk mengecek output dalam presentasi yang nantinya akan menjadi acuan untuk menentukan keputusan terhadap missing values

# %%
df_file[df_file['salaryTerm'].isnull()]
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 3      standout        508,193
# 4      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName            companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...               439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak               428988
# 2                        Pendidikan/Pelatihan,Pendidikan               428988
# 3      Komputer/Teknologi Informasi,IT-Admin Jaringan...  jobstreet-id-184662
# 4                        Pendidikan/Pelatihan,Pendidikan               428988
# ...                                                  ...                  ...
# ...

# %% [markdown]
# menampilkan nilai kosong dari salary Term

# %%
df_file[df_file['salaryMin'].isnull()]
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 4      standard        507,105
# 7      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...    439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak    428988
# 2                        Pendidikan/Pelatihan,Pendidikan    428988
# 4                        Pendidikan/Pelatihan,Pendidikan    428988
# 7                        Pendidikan/Pelatihan,Pendidikan    428988
# ...                                                  ...       ...
# 27672            Manufaktur,Pembelian/Manajemen Material    437038
# ...

# %% [markdown]
# menampilkan nilai kosong dari salary Min

# %%
df_file[df_file['salaryMax'].isnull()]
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 4      standard        507,105
# 7      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...    439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak    428988
# 2                        Pendidikan/Pelatihan,Pendidikan    428988
# 4                        Pendidikan/Pelatihan,Pendidikan    428988
# 7                        Pendidikan/Pelatihan,Pendidikan    428988
# ...                                                  ...       ...
# 27672            Manufaktur,Pembelian/Manajemen Material    437038
# ...

# %% [markdown]
# menampilkan nilai kosong dari salary Max

# %%
df_file[df_file['salarycurrency'].isnull()]
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 4      standard        507,105
# 7      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...    439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak    428988
# 2                        Pendidikan/Pelatihan,Pendidikan    428988
# 4                        Pendidikan/Pelatihan,Pendidikan    428988
# 7                        Pendidikan/Pelatihan,Pendidikan    428988
# ...                                                  ...       ...
# 27672            Manufaktur,Pembelian/Manajemen Material    437038
# ...

# %% [markdown]
# menampilkan nilai kosong dari salary currency

# %%
df_file[df_file['sellingPoints'].isnull()]
# Out:
#          adType categoriesCode  \
# 0      standard        502,137
# 1      standard        508,191
# 2      standard        507,105
# 3      standout        508,193
# 4      standard        507,105
# ...         ...            ...
# 27672  standout        510,140
# 27673  standard        503,145
# 27674  standard        503,145
# 27675  standard        502,133
# 27676  standard        505,119
#
#                                           categoriesName            companyId  \
# 0      Sumber Daya Manusia/Personalia,Sumber Daya Man...               439784
# 1        Komputer/Teknologi Informasi,IT-Perangkat Lunak               428988
# 2                        Pendidikan/Pelatihan,Pendidikan               428988
# 3      Komputer/Teknologi Informasi,IT-Admin Jaringan...  jobstreet-id-184662
# 4                        Pendidikan/Pelatihan,Pendidikan               428988
# ...                                                  ...                  ...
# ...

# %% [markdown]
# menampilkan nilai kosong dari sellingPoints

# %%
df_file[df_file['employment'].isnull()]
# Out:
#                adType categoriesCode  \
# 44     auto_inclusion        510,115
# 47     auto_inclusion        506,114
# 50     auto_inclusion        503,142
# 51     auto_inclusion        508,191
# 52     auto_inclusion        508,191
# ...               ...            ...
# 22096  auto_inclusion        503,145
# 22238  auto_inclusion        503,139
# 22353  auto_inclusion        508,193
# 22421  auto_inclusion        503,139
# 22541  auto_inclusion        508,191
#
#                                           categoriesName  \
# 44                               Manufaktur,Pemeliharaan
# 47                       Hotel/Restoran,Hotel/Pariwisata
# 50           Penjualan / Pemasaran,Penjualan - Korporasi
# 51       Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 52       Komputer/Teknologi Informasi,IT-Perangkat Lunak
# ...                                                  ...
# 22096              Penjualan / Pemasaran,Penjualan Ritel
# ...

# %% [markdown]
# menampilkan nilai kosong dari employment

# %%
df_file[df_file['companyName'].isnull()]
# Out:
#          adType categoriesCode  \
# 25     standard        510,194
# 26     standard        510,194
# 30     standard        510,197
# 32     standard        510,194
# 33     standard        502,146
# ...         ...            ...
# 27629  standout        502,133
# 27655  standout        509,190
# 27656  standout        509,187
# 27657  standout        509,190
# 27658  standout        509,190
#
#                                           categoriesName companyId  \
# 25                                 Manufaktur,Manufaktur       NaN
# 26                                 Manufaktur,Manufaktur       NaN
# 30                   Manufaktur,Penjaminan Kualitas / QA       NaN
# 32                                 Manufaktur,Manufaktur       NaN
# 33             Sumber Daya Manusia/Personalia,Sekretaris       NaN
# ...                                                  ...       ...
# 27629  Sumber Daya Manusia/Personalia,Staf / Administ...       NaN
# ...

# %% [markdown]
# menampilkan nilai kosong dari companyName

# %%
df_file[df_file['companyId'].isnull()]
# Out:
#          adType categoriesCode  \
# 25     standard        510,194
# 26     standard        510,194
# 30     standard        510,197
# 32     standard        510,194
# 33     standard        502,146
# ...         ...            ...
# 27629  standout        502,133
# 27655  standout        509,190
# 27656  standout        509,187
# 27657  standout        509,190
# 27658  standout        509,190
#
#                                           categoriesName companyId  \
# 25                                 Manufaktur,Manufaktur       NaN
# 26                                 Manufaktur,Manufaktur       NaN
# 30                   Manufaktur,Penjaminan Kualitas / QA       NaN
# 32                                 Manufaktur,Manufaktur       NaN
# 33             Sumber Daya Manusia/Personalia,Sekretaris       NaN
# ...                                                  ...       ...
# 27629  Sumber Daya Manusia/Personalia,Staf / Administ...       NaN
# ...

# %% [markdown]
# menampilkan nilai kosong dari companyId

# %%
df_file = df_file.drop('salaryTerm',axis=1)

# %% [markdown]
# dikarenakan presentasi untuk salaryTerm sangat tinggi yaitu diatas 70% maka kolom akan dihapus

# %% [markdown]
# ###Imputasi Missing Values

# %%
df_file['salaryMin'].dropna().describe()
# Out:
# count    7.147000e+03
# mean     5.989785e+06
# std      6.807645e+06
# min      6.000000e+00
# 25%      3.500000e+06
# 50%      4.500000e+06
# 75%      6.500000e+06
# max      4.000000e+08
# Name: salaryMin, dtype: float64

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada salaryMin terdapat missing values dibawah 70%

# %%
df_file['salaryMin'] = df_file['salaryMin'].fillna(df_file['salaryMin'].dropna().mean())

# %% [markdown]
# dari hasil analisis statistik sebelumnya maka dapat digunakan mean

# %%
df_file['salaryMax'].dropna().describe()
# Out:
# count    7.147000e+03
# mean     8.529533e+06
# std      1.099144e+07
# min      9.000000e+00
# 25%      4.900000e+06
# 50%      6.300000e+06
# 75%      9.800000e+06
# max      7.000000e+08
# Name: salaryMax, dtype: float64

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada salaryMax terdapat missing values dibawah 70%

# %%
df_file['salaryMax'] = df_file['salaryMax'].fillna(df_file['salaryMax'].dropna().mean())

# %% [markdown]
# dari hasil analisis statistik sebelumnya maka dapat digunakan mean

# %%
df_file['companyId'].dropna().describe()
# Out:
# count      26789
# unique     10569
# top       390146
# freq         251
# Name: companyId, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada companyId terdapat missing values dibawah 70%

# %%
df_file['companyId'].fillna('UNKNOWN', inplace=True)

# %%
df_file['salarycurrency'].dropna().describe()
# Out:
# count     7150
# unique       5
# top        IDR
# freq      7127
# Name: salarycurrency, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada salarycurrenccy terdapat missing values dibawah 70%

# %%
df_file['salarycurrency'].mode()
## cek duplikat
# Out:
# 0    IDR
# Name: salarycurrency, dtype: object

# %%
df_file['salarycurrency'] = df_file['salarycurrency'].fillna(df_file['salarycurrency'].mode()[0])

# %%
df_file['companyName'].dropna().describe()
# Out:
# count                              26789
# unique                             10723
# top       Shopee Internasional Indonesia
# freq                                 228
# Name: companyName, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada companyName terdapat missing values dibawah 70%

# %%
df_file['companyName'].mode()
## cek duplikat
# Out:
# 0    Shopee Internasional Indonesia
# Name: companyName, dtype: object

# %%
df_file['companyName'] = df_file['companyName'].fillna(df_file['companyName'].mode()[0])

# %%
df_file['employment'].dropna().describe()
# Out:
# count         26150
# unique           12
# top       full_time
# freq          22611
# Name: employment, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada employment terdapat missing values dibawah 70%

# %%
df_file['employment'].mode()
## cek duplikat
# Out:
# 0    full_time
# Name: employment, dtype: object

# %%
df_file['employment'] = df_file['employment'].fillna(df_file['employment'].mode()[0])

# %%
df_file['locations'].dropna().describe()
# Out:
# count            27643
# unique            1514
# top       Jakarta Raya
# freq              5694
# Name: locations, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada locations terdapat missing values dibawah 70%

# %%
df_file['locations'].mode()
## cek duplikat
# Out:
# 0    Jakarta Raya
# Name: locations, dtype: object

# %%
df_file['locations'] = df_file['locations'].fillna(df_file['locations'].mode()[0])

# %%
df_file['sellingPoints'].dropna().describe()
# Out:
# count                                                  4090
# unique                                                 3223
# top       BPJS Kesehatan dan Ketenagakerjaan,Bonus Kiner...
# freq                                                     50
# Name: sellingPoints, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada sellingPoints terdapat missing values dibawah 70%

# %%
df_file['sellingPoints'].mode()
## cek duplikat
# Out:
# 0    BPJS Kesehatan dan Ketenagakerjaan,Bonus Kiner...
# Name: sellingPoints, dtype: object

# %%
df_file['sellingPoints'] = df_file['sellingPoints'].fillna(df_file['sellingPoints'].mode()[0])

# %%
df_file['salaryPeriod'].dropna().describe()
# Out:
# count       27674
# unique          1
# top       monthly
# freq        27674
# Name: salaryPeriod, dtype: object

# %% [markdown]
# pada bagian ini dilakukan pengecekan dikarenakan pada salaryPeriod terdapat missing values dibawah 70%

# %%
df_file['salaryPeriod'].mode()
## cek duplikat
# Out:
# 0    monthly
# Name: salaryPeriod, dtype: object

# %%
df_file['salaryPeriod'] = df_file['salaryPeriod'].fillna(df_file['salaryPeriod'].mode()[0])

# %%
print((df_file.isna().sum() / len(df_file)) * 100)
# Out:
# adType             0.0
# categoriesCode     0.0
# categoriesName     0.0
# companyId          0.0
# companyName        0.0
# companyPrivate     0.0
# description        0.0
# employment         0.0
# id                 0.0
# isClassified       0.0
# isStandout         0.0
# jobTitle           0.0
# jobUrl             0.0
# locations          0.0
# postingDuration    0.0
# postedAt           0.0
# salarycurrency     0.0
# salaryMin          0.0
# salaryMax          0.0
# salaryPeriod       0.0
# sellingPoints      0.0
# dtype: float64

# %% [markdown]
# ##**Penanganan Duplicated Data**

# %% [markdown]
# ###Pengecekan Nilai Duplikat

# %%
df_file[df_file.duplicated()]
# Out:
# Empty DataFrame
# Columns: [adType, categoriesCode, categoriesName, companyId, companyName, companyPrivate, description, employment, id, isClassified, isStandout, jobTitle, jobUrl, locations, postingDuration, postedAt, salarycurrency, salaryMin, salaryMax, salaryPeriod, sellingPoints]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Dapat Dilihat bahwa tidak ada nilai duplikat

# %% [markdown]
# ###Penanganan Outliers

# %%
results = []

cols = df_file.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_file[col].quantile(0.25)
  q3 = df_file[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_file[(df_file[col] < lower_bound) | (df_file[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_file))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom      Persentase Outliers
# id                    6.723995
# salaryMin            25.822885
# salaryMax            25.822885

# %%
boxplot = df_file.drop('id', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# ##**Construct Data**

# %% [markdown]
# ###Melakukan Rekayasa Fitur (Feature Engineering)

# %%
def categorize_location(location):
    if "jakarta" in location.lower():
        return 'Jakarta'
    else:
        return 'Luar Jakarta'

# Menambahkan kolom LocationCategory ke DataFrame
df_file['LocationCategory'] = df_file['locations'].apply(categorize_location)

# %% [markdown]
# pada bagian ini untuk lokasi dipersempit lagi hanya menjadi jakarta dan luar jakarta

# %%
df_file.head()
# Out:
#      adType categoriesCode                                     categoriesName  \
# 0  standard        502,137  Sumber Daya Manusia/Personalia,Sumber Daya Man...
# 1  standard        508,191    Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 2  standard        507,105                    Pendidikan/Pelatihan,Pendidikan
# 3  standout        508,193  Komputer/Teknologi Informasi,IT-Admin Jaringan...
# 4  standard        507,105                    Pendidikan/Pelatihan,Pendidikan
#
#              companyId             companyName  companyPrivate  \
# 0               439784        MODENA INDONESIA           False
# 1               428988  Yayasan Bina Nusantara           False
# 2               428988  Yayasan Bina Nusantara           False
# 3  jobstreet-id-184662              GriyaBayar           False
# 4               428988  Yayasan Bina Nusantara           False
#
#                                          description employment       id  \
# ...

# %% [markdown]
# ##**Data Reduction**

# %% [markdown]
# ###Mengurangi Fitur-Fitur Yang Kurang Relevan

# %%
df_file = df_file.drop(['categoriesCode','companyId', 'companyPrivate', 'id', 'description', 'salarycurrency', 'isClassified', 'isStandout', 'jobUrl', 'postingDuration', 'postedAt', 'postedAt','locations', 'sellingPoints'],axis=1)

# %%
df_file.head()
# Out:
#      adType                                     categoriesName  \
# 0  standard  Sumber Daya Manusia/Personalia,Sumber Daya Man...
# 1  standard    Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 2  standard                    Pendidikan/Pelatihan,Pendidikan
# 3  standout  Komputer/Teknologi Informasi,IT-Admin Jaringan...
# 4  standard                    Pendidikan/Pelatihan,Pendidikan
#
#               companyName employment  \
# 0        MODENA INDONESIA  full_time
# 1  Yayasan Bina Nusantara  full_time
# 2  Yayasan Bina Nusantara  full_time
# 3              GriyaBayar  full_time
# 4  Yayasan Bina Nusantara  full_time
#
#                                             jobTitle     salaryMin  \
# 0                     Human Capital Business Partner  5.989785e+06
# 1          UX Mentor (Apple Developer Academy BINUS)  5.989785e+06
# 2  Lecturer Specialist - S2 Entrepreneurship (Bin...  5.989785e+06
# 3                       Junior Network Administrator  5.500000e+06
# ...

# %%
df_string1 = df_file['categoriesName']
df2 = df_file.drop(columns=['categoriesName'])

df2
# Out:
#          adType                        companyName  employment  \
# 0      standard                   MODENA INDONESIA   full_time
# 1      standard             Yayasan Bina Nusantara   full_time
# 2      standard             Yayasan Bina Nusantara   full_time
# 3      standout                         GriyaBayar   full_time
# 4      standard             Yayasan Bina Nusantara   full_time
# ...         ...                                ...         ...
# 27672  standout                       PT SMART,Tbk  internship
# 27673  standard               PT Mega Auto Finance   full_time
# 27674  standard               PT Mega Auto Finance   full_time
# 27675  standard               PT Mega Auto Finance   full_time
# 27676  standard  PT. Salam Pacific Indonesia Lines    contract
#
#                                                 jobTitle     salaryMin  \
# 0                         Human Capital Business Partner  5.989785e+06
# ...

# %%
df_string2 = df2['companyName']
df3 = df2.drop(columns=['companyName'])

df3
# Out:
#          adType  employment  \
# 0      standard   full_time
# 1      standard   full_time
# 2      standard   full_time
# 3      standout   full_time
# 4      standard   full_time
# ...         ...         ...
# 27672  standout  internship
# 27673  standard   full_time
# 27674  standard   full_time
# 27675  standard   full_time
# 27676  standard    contract
#
#                                                 jobTitle     salaryMin  \
# 0                         Human Capital Business Partner  5.989785e+06
# 1              UX Mentor (Apple Developer Academy BINUS)  5.989785e+06
# 2      Lecturer Specialist - S2 Entrepreneurship (Bin...  5.989785e+06
# 3                           Junior Network Administrator  5.500000e+06
# 4                                  Subject Teacher (ICT)  5.989785e+06
# ...                                                  ...           ...
# 27672                             Internship Procurement  5.989785e+06
# ...

# %%
df_string3 = df3['employment']
df4 = df3.drop(columns=['employment'])

df4
# Out:
#          adType                                           jobTitle  \
# 0      standard                     Human Capital Business Partner
# 1      standard          UX Mentor (Apple Developer Academy BINUS)
# 2      standard  Lecturer Specialist - S2 Entrepreneurship (Bin...
# 3      standout                       Junior Network Administrator
# 4      standard                              Subject Teacher (ICT)
# ...         ...                                                ...
# 27672  standout                             Internship Procurement
# 27673  standard                  BRANCH MANAGER CAR - JAKARTA AREA
# 27674  standard               BRANCH MANAGER CAR - KALIMANTAN AREA
# 27675  standard                     ADMINISTRASI MOBIL - SAMARINDA
# 27676  standard                                     Security Guard
#
#           salaryMin     salaryMax salaryPeriod LocationCategory
# 0      5.989785e+06  8.529533e+06      monthly          Jakarta
# ...

# %%
df_string4 = df4['jobTitle']
df5 = df4.drop(columns=['jobTitle'])

df5
# Out:
#          adType     salaryMin     salaryMax salaryPeriod LocationCategory
# 0      standard  5.989785e+06  8.529533e+06      monthly          Jakarta
# 1      standard  5.989785e+06  8.529533e+06      monthly     Luar Jakarta
# 2      standard  5.989785e+06  8.529533e+06      monthly     Luar Jakarta
# 3      standout  5.500000e+06  7.700000e+06      monthly     Luar Jakarta
# 4      standard  5.989785e+06  8.529533e+06      monthly     Luar Jakarta
# ...         ...           ...           ...          ...              ...
# 27672  standout  5.989785e+06  8.529533e+06      monthly          Jakarta
# 27673  standard  5.989785e+06  8.529533e+06      monthly          Jakarta
# 27674  standard  5.989785e+06  8.529533e+06      monthly     Luar Jakarta
# 27675  standard  5.989785e+06  8.529533e+06      monthly     Luar Jakarta
# 27676  standard  5.989785e+06  8.529533e+06      monthly          Jakarta
#
# [27677 rows x 5 columns]

# %% [markdown]
# ##**Data Transformation**

# %% [markdown]
# ###Mapping

# %%
df5['adType'] = df5['adType'].map({'standard': 0, 'standout': 1, 'auto_inclusion':2})
df5['salaryPeriod'] = df5['salaryPeriod'].map({'monthly': 0})
df5['LocationCategory'] = df5['LocationCategory'].map({'Jakarta': 0, 'Luar Jakarta': 1})

# %%
df_file
# Out:
#          adType                                     categoriesName  \
# 0      standard  Sumber Daya Manusia/Personalia,Sumber Daya Man...
# 1      standard    Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 2      standard                    Pendidikan/Pelatihan,Pendidikan
# 3      standout  Komputer/Teknologi Informasi,IT-Admin Jaringan...
# 4      standard                    Pendidikan/Pelatihan,Pendidikan
# ...         ...                                                ...
# 27672  standout            Manufaktur,Pembelian/Manajemen Material
# 27673  standard              Penjualan / Pemasaran,Penjualan Ritel
# 27674  standard              Penjualan / Pemasaran,Penjualan Ritel
# 27675  standard  Sumber Daya Manusia/Personalia,Staf / Administ...
# 27676  standard                      Pelayanan,Angkatan Bersenjata
#
#                              companyName  employment  \
# 0                       MODENA INDONESIA   full_time
# ...

# %%
df5.nunique()
# Out:
# adType                3
# salaryMin           294
# salaryMax           416
# salaryPeriod          1
# LocationCategory      2
# dtype: int64

# %% [markdown]
# ##**Modelling Data**

# %% [markdown]
# ###Library untuk Splitting Data dan Normalisasi Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ###Library untuk Build Model

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

from sklearn.metrics import accuracy_score

# %%
df5.head()
# Out:
#    adType     salaryMin     salaryMax  salaryPeriod  LocationCategory
# 0       0  5.989785e+06  8.529533e+06             0                 0
# 1       0  5.989785e+06  8.529533e+06             0                 1
# 2       0  5.989785e+06  8.529533e+06             0                 1
# 3       1  5.500000e+06  7.700000e+06             0                 1
# 4       0  5.989785e+06  8.529533e+06             0                 1

# %% [markdown]
# ##**Modelling Predict**

# %% [markdown]
# ###Pre-Processing

# %% [markdown]
# ####Split Data

# %%
x = df5.drop('LocationCategory', axis=1)
y = df5['LocationCategory']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Pada baris di atas menunjukan bahwa variabel 'x' berisi kolom yang akan diprediksi, sedangkan pada variabel 'y' berisi target kolom yang akan di prediksi. pada syntax tersebut terdapat x_train yang berisi informasi yang akan diajarkan kepada model yang kemudian dapat digunakan untuk memprediksi data baru, sedangkan x_test digunakan untuk menguji x_train tersebut. begitu juga y_train yang digunakan untuk mempredimsi data target dan y_test untuk menguji y_train tersebut.
#
# Split data ini digunakan untuk membagi dataset menjadi dua yaitu training data dan testing data. training data digunakan untuk melatih model dengan mengidentifikasi pola yang ada, sementara data uji adalah data yang digunakan untuk menguji seberapa baik model. Dengan adanya split data ini maka data memungkinkan untuk membangun dan menguji model dengan baik, meningkatkan akurasi prediksi dan memastikan bahwa model dapat bekerja dengan baik.

# %% [markdown]
# ####Normalisasi Data

# %%
scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(x_train)

x_test_scaled = scaler.fit_transform(x_test)

# %%
df5
# Out:
#        adType     salaryMin     salaryMax  salaryPeriod  LocationCategory
# 0           0  5.989785e+06  8.529533e+06             0                 0
# 1           0  5.989785e+06  8.529533e+06             0                 1
# 2           0  5.989785e+06  8.529533e+06             0                 1
# 3           1  5.500000e+06  7.700000e+06             0                 1
# 4           0  5.989785e+06  8.529533e+06             0                 1
# ...       ...           ...           ...           ...               ...
# 27672       1  5.989785e+06  8.529533e+06             0                 0
# 27673       0  5.989785e+06  8.529533e+06             0                 0
# 27674       0  5.989785e+06  8.529533e+06             0                 1
# 27675       0  5.989785e+06  8.529533e+06             0                 1
# 27676       0  5.989785e+06  8.529533e+06             0                 0
#
# [27677 rows x 5 columns]

# %% [markdown]
# Pada bagian Normalisasi ini bertujuan mengubah skala nilai-nilai dalam dataset agar lebih mudah diproses. Pada baris pertama dilakukan pembuatan objek scaler yang digunakan untuk mengubah skala data yang kemudian akan dilakukan penskalaan Min-Max pada x-train. hal ini bermaksud untuk menghitung nilai minimum dan maksimum lalu mengubah ke dalam rentang 0 dan 1. hal ini juga dilakukan pada x_test untuk memastikan konsistensi antara kedua data. Normalisasi ini dilakukan agar model dapat dijalankan tanpa terganggu oleh perbedaan skala antar fitur-fitur dalam dataset

# %% [markdown]
# ###Build and Train Model

# %% [markdown]
# ####Gaussian Naive Bayes

# %%
gnb = GaussianNB()

gnb.fit(x_train_scaled, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Gaussian NB digunakan untuk memprediksi kategori atau label dari data berdasarkan nilai yang diberikan. Dalam konteks ini GNB digunakan untuk melakukan klasifikasi pada data yang telah diubah skala menjadi rentang antara 0 dan 1. GNB memanfaatkan informasi mengenai 'locationcategory' untuk melakukan prediksi.

# %% [markdown]
# ####K-Nearest Neighbor

# %%
knn = KNeighborsClassifier()

knn.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# K-Nearest Neighbor digunakan untuk memprediksi kategori atau label berdasarkan x_train yang terdekat dengan data yang akan diprediksi. Data yang memiliki kemiripan cenderung memiliki label yang sama. KNN digunakan untuk melakukan klasifikasi pada data. Model ini akan mengamati dan mengingat pola pada x_train yang telah diubah skala. saat memprediksi data baru, KNN akan menemukan titik K titik data x_traom terdekat dengan data baru dan kemudian akan memprediksi label dari data baru berdasarkan mayoritas label dari K. KNN memanfaatkan konsep jarak dan kesamaan fitur untuk melakukan klasifikasi pada data sebelumnya.

# %% [markdown]
# ####Decision Tree

# %%
dtc = DecisionTreeClassifier()

dtc.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Decision Tree adalah algoritma yang digunakan untuk memprediksi berdasarkan aturan keputusan yang dihasilkan daripohon keputusan. Konsep dari Decision Tree adalah membagi data berdasarkan fitur yang paling informatif sehingga setiap cabang akan mewakili keputusan dalam fitur. pada metode .fit()dengan data x_train_scaled dan y_train maka decision tree akan mempelajari pola pada x_train_scaled yang telah diubah skala untuk membangun pohon keputusan. algoritma akan memilih fitur yang paling baik dalam memisahkan kelas dan memprediksi data baru dengan mengikuti aturan yang telah dipelajari dari pohon keputusan. Decision Tree digunakan untuk klasifikasi pada data berdasarkan aturan keputusan yang telah dipelahari dari x_train yang telah discaling.

# %% [markdown]
# ###Begins and Compare Predict

# %%
gnb_pred = gnb.predict(x_test_scaled)
knn_pred = knn.predict(x_test_scaled)
dtc_pred = dtc.predict(x_test_scaled)

# %% [markdown]
# Pada kode di atas dilakukan prediksi kategori atau label dari data uji yaitu x_test_scaled. pada model Gaussian Naive Bayes, K-Nearest Neighbors dan Decision Tree maka dilakukan prediksi data uji, setiap model akan memprediksi sesuai dengan algoritma yang digunakan berdasarkan aturan atau probabilitas yang telah dipelajari. lalu hasil prediksi akan disimpan pada 'gnb_pred', 'knn_pred' dan 'dtc_pred'. dengan demikian maka memungkinkan untuk memperoleh prediksi dari berbagai model dan membandingkan kinerja untuk setuap algoritma klasifikasi.

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/amaliakartikasari/Mini-Project-Data-Mining/main/Check%20Point%204/Data%20Cleaned%20Fix%20(1).csv')

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)

y_test = pd.DataFrame(y_test).reset_index(drop=True)

gnb_col = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction"])
knn_col = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction"])
dtc_col = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# Kode diatas digunakan untuk menggabungkan hasil prediksi dari setiap model dengan data uji yang sesuai. pada x_test dengan target y_test akan diubah menjadi dataframe dan direset indeksnya agar sesuai dengan urutan data. hasil dari ketiga model akan diubah menjadi dataframe dengan nama kolom yang sesuai yang kemudian akan menggabungkan dataframe, target dan hasil prediksi dari ketiga kolom menggunakan pd.concat.

# %%
combined_data
# Out:
#       adType     salaryMin     salaryMax  salaryPeriod  LocationCategory  \
# 0          0  4.400000e+06  5.500000e+06             0                 0
# 1          0  3.000000e+06  5.000000e+06             0                 1
# 2          0  5.989785e+06  8.529533e+06             0                 1
# 3          0  5.989785e+06  8.529533e+06             0                 1
# 4          1  3.500000e+06  4.900000e+06             0                 0
# ...      ...           ...           ...           ...               ...
# 8299       0  5.989785e+06  8.529533e+06             0                 1
# 8300       0  5.989785e+06  8.529533e+06             0                 1
# 8301       0  5.989785e+06  8.529533e+06             0                 1
# 8302       0  3.700000e+06  5.180000e+06             0                 1
# 8303       1  5.989785e+06  8.529533e+06             0                 1
#
#       gnb_prediction  knn_prediction  dtc_prediction
# ...

# %% [markdown]
# Kode tersebut memungkinkan untuk melihat hasil prediksi secara bersamaan untuk analisa lebih lanjut

# %% [markdown]
# ##**Modelling Associate**

# %% [markdown]
# ###Pre-Processing

# %% [markdown]
# ####Adjusment

# %%
x_final = df5.drop("salaryPeriod", axis=1)

# %% [markdown]
# Penghapusan Kolom yang kurang relevan dengan dataset.

# %% [markdown]
# ####Normalisasi Data

# %%
scaler = MinMaxScaler()

x_final_norm = scaler.fit_transform(x_final)

# %% [markdown]
# Pada kolom ini dilakukan penskalaan Min-Max pada x_final. onjek scaler akan digunakan untuk mengubah skala nilai dalam data x_final agar berada pada rentang 0 dan 1 yang kemudian akan menggunakan fit_transform() dari objek scaler. data x_final akan diubah skala sesuai dengan nilai minimum dan maksimum dari setiap fitur. hal ini akan menghasilkan x_final_norm yaitu data x_final yang telah discaling

# %% [markdown]
# ####Validasi Silang

# %%
inertia_values = []

k_range = range(2, 10)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x_final_norm)
    inertia_values.append(kmeans.inertia_)

plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.xticks(k_range)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# ...

# %% [markdown]
# Pada metode elbow ini dapat dilihat bahwa nnilai optimal dari klaster adalah 4. hal ini dilakukan dengan melakukan definisilist kosong pada 'inertia_values' yang digunakan sebagai penyimpanan nilai inertia dari iterasi untuk setiap klaster. untuk rentang nilai klaster yang akan dieksplorasi adalah 2-9. setiap hasil inertia dari model akan disimpan pada 'inertia_values'. setelah selesai maka dapat dilihat hasilnya dengan plot garis dan dilihat bahwa siku atau 'elbow' pada grafik ditunjukan pada nilai klaster 4

# %% [markdown]
# ###Build Model

# %% [markdown]
# ####K-Means

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# K-Means adalah algoritma klasterisasi yang digunakan untuk mengelompokkan data menjadi klaster atau kelompok yang memiliki karakteristik atau pola yang serupa berdasarkan atribut yang dimiliki. pada kode tersebut akan dilakukan pembuatan model K-Means dengan 4 klaster menggunakan data x_final_norm. langkah pertama adalah membuat objek K-Means dengan menyebutkan jumlah klaster yang diinginkan yaitu 4 dan menyertakan oarameter yaitu 'random_state-42' yang berguna untuk mengatur keacakan dan membuat hasil yang dapat direproduksi. selanjutkannya adalah melatih model dengan skala yang diubah yaitu 'x_final_norm' agar model dapat dikelompokkan menjadi 4 berdasarkan pola yang ada.

# %% [markdown]
# ####Hierarchical Clustering

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')

# %% [markdown]
# Hierarchical Clustering adalah pengelompokan data ke dalam kelompok atau klaster hierarkis berdasarkan tingkat kesamaan atau jarak antar data. pada kode tersebut, dilakukan pembuatan objek AgglomerativeClustering dengan menyebutkan jumlah klaster yang diinginkan (dalam hal ini 4 klaster) menggunakan parameter n_clusters=4. selain itu untuk menentukan jenis jarak atau affinity yang digunakan untuk mengukur kedekatan antara data, dalam hal ini menggunakan 'euclidean' untuk mengukur jarak Euclidean. Parameter linkage='ward' digunakan untuk menentukan metode penggabungan klaster yang digunakan, di mana 'ward' adalah salah satu metode yang mengoptimalkan pengurangan varian dalam klaster.

# %% [markdown]
# ###Begins and Compare Clusters

# %%
kmeans_clust = kmeans.predict(x_final_norm)
hierarchy_clust = hc.fit_predict(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %% [markdown]
# pada kode tersebut digunakan untuk memprediksi klaster pada data menggunakan dua jenis algoritma yaitu 'kmeans.predict(x_final_norm)' untuk mempredikasi data menggunakan model K-Means yang akan disimpan pada 'kmeans_clust'. selanjutnya adalah 'hc.fit.predict(x_final_norm)' yang digunakan untuk klasterisasi menggunakan agglomerative clustering dan langsung disimpan dalam variabel 'hierarchy_clust'.

# %%
x_final = pd.DataFrame(x_final).reset_index(drop=True)

kmeans_col = pd.DataFrame(kmeans_clust, columns=["kmeans_cluster"])
hierarchy_col = pd.DataFrame(hierarchy_clust, columns=["hierarchy_cluster"])

combined_data_assoc = pd.concat([x_final, kmeans_col, hierarchy_col], axis=1)

# %% [markdown]
# Kode di atas digunakan untuk menggabungkan hasil prediksi klaster dari dua algoritma klasterisasi yang berbeda yaitu K-Means dan Hierarchy. pada data asli yaitu 'x_final' akan diubah menjadi dataframe dan direset agar indeksnya sesuai dengan urutan data. pada hasil predikasi dari K-Menas dan Hierarchy akan diubah menjadi nama kolom yang sesuai yaitu 'kmeans_cluster' dan hierarchy_cluster'. dengan menggunakan pd.concat maka akan dilakukan penggabungan dataframe, data asli, hasil predikasi K-Means, dan hasil predikasi Agglomerative Clustering menjadi satu yaitu 'combined_data_assoc'.

# %%
combined_data_assoc.head()
# Out:
#    adType     salaryMin     salaryMax  LocationCategory  kmeans_cluster  \
# 0       0  5.989785e+06  8.529533e+06                 0               3
# 1       0  5.989785e+06  8.529533e+06                 1               0
# 2       0  5.989785e+06  8.529533e+06                 1               0
# 3       1  5.500000e+06  7.700000e+06                 1               2
# 4       0  5.989785e+06  8.529533e+06                 1               0
#
#    hierarchy_cluster
# 0                  2
# 1                  3
# 2                  3
# 3                  1
# 4                  3

# %% [markdown]
# Kode di atas digunakan untuk menaqmpilkan lima baris pertama yang merupakan hasil dari penggabungan data asli dengan hasil prediksi klaster dari dua algoritma klasterisasi yang berbeda.

# %%
df_final = pd.concat([combined_data_assoc, df_string1, df_string2, df_string3, df_string4], axis = 1)
df_final
# Out:
#        adType     salaryMin     salaryMax  LocationCategory  kmeans_cluster  \
# 0           0  5.989785e+06  8.529533e+06                 0               3
# 1           0  5.989785e+06  8.529533e+06                 1               0
# 2           0  5.989785e+06  8.529533e+06                 1               0
# 3           1  5.500000e+06  7.700000e+06                 1               2
# 4           0  5.989785e+06  8.529533e+06                 1               0
# ...       ...           ...           ...               ...             ...
# 27672       1  5.989785e+06  8.529533e+06                 0               1
# 27673       0  5.989785e+06  8.529533e+06                 0               3
# 27674       0  5.989785e+06  8.529533e+06                 1               0
# 27675       0  5.989785e+06  8.529533e+06                 1               0
# 27676       0  5.989785e+06  8.529533e+06                 0               3
#
# ...

# %% [markdown]
# Kode tersebut bertujuan untuk menggabungkan DataFrame combined_data_assoc dengan empat DataFrame lain (df_string1, df_string2, df_string3, df_string4) secara horizontal (disebut juga concatenation axis=1), sehingga menghasilkan DataFrame baru yang disebut df_final. Dengan menggunakan metode pd.concat dan menyertakan parameter axis=1, kita menggabungkan DataFrame-data hasil klasterisasi dengan DataFrame-data string (data yang berisi teks atau kategorikal) secara berdampingan berdasarkan indeksnya.

# %% [markdown]
# ###Model

# %%
px.imshow(df_final.corr(numeric_only=True))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# dari visualiasi di atas dapat dilihat bahwa adType paling tidak memiliki pengaruh dengan hierarchy_cluster, untuk salaryMin, salaryMax, LocationCategory, dan kmeans_cluster tidak berpengaruh namun masih diatas 0.
#
# sedangkan pada salaryMin, variabel yang paling berpengaruh adalah salaryMax. begitupun sebaliknya.
#
# pada LocationCategory, variabel yang paling tidak berpengaruh adalah kmeans_cluster sedangkan yang paling berpengaruh adalah hierarchy_cluster.
#
# pada kmeans_cluster variabel LocationCategory sangat rendah seperti variabel hierarchy_cluster. namun variabel hierarchy_cluster memiliki peningkatan lebih daripada LocationCategory
#
# pada hirarchy_cluster, variabel adType sangat tidak berpengaruh. sedangkan kmeans_cluster memiliki pengaruh walau masih dibawah 0. pada hirarchy_cluster, LocationCategory sangat berpengaruh.

# %%
import pandas as pd
import numpy as np

# Sample data
data = {
    'kmeans_cluster': np.random.randint(0, 5, 100),  # Random integers for kmeans_cluster
    'hierarchy_cluster': np.random.randint(0, 3, 100),  # Random integers for hierarchy_cluster (optional)
}
df_final = pd.DataFrame(data)

# Your plotting code (modified to use df_final)
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

kmeans_counts = df_final['kmeans_cluster'].value_counts()
kmeans_labels = list(kmeans_counts.index)
kmeans_values = list(kmeans_counts.values)
ax1.bar(kmeans_labels, kmeans_values, color=['blue' if i == 0 else 'gray' for i in range(len(kmeans_values))])
ax1.set_xlabel('Kmeans Cluster')
ax1.set_ylabel('Count')
ax1.set_title('Kmeans Clusters Distribution')

if 'hierarchy_cluster' in df_final.columns:
    hierarchy_counts = df_final['hierarchy_cluster'].value_counts()
    hierarchy_labels = list(hierarchy_counts.index)
    hierarchy_values = list(hierarchy_counts.values)
    ax2.bar(hierarchy_labels, hierarchy_values, color=['blue' if i == 0 else 'gray' for i in range(len(hierarchy_values))])
    ax2.set_xlabel('Hierarchy Cluster')
    ax2.set_ylabel('Count')
    ax2.set_title('Hierarchy Clusters Distribution')
else:
    ax2.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# pada Visualisasi di atas dapat dilihat pada kmeans_cluster bahwa cluster 3memiliki jumlah yang lebih besar daripada yang lain. sedangkan pada hierarchy cluster distribusi cluster 1 lebih mendominasi.
